# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import random

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

onefig_size = (10,4)
multifigs_size = (12,4)

# %%
1 DATA OVERVIEW
# Out:
#   Cell In[14], line 1
#     DATA OVERVIEW
#          ^
# SyntaxError: invalid syntax

# %%
1.Trip ID:A unique identifier for each traveler's trip.
2.Destination:Name of the city or country the visitor has visited.
3.Start date:The date the visitor begins the trip.
4.End date:The date the visitor ends the trip.
5.Duration (days):The number of days visitors spend during the trip.
6.Traveler name:The visitor's name.
7.Traveler age:Age of tourist at the time of trip.
8.Traveler gender:The tourist's gender.
9.Traveler nationality:Nationality of tourists.
10.Accommodation type:The type of accommodation the traveler has stayed in, such as a hotel, hostel or Airbnb.
11.Accommodation cost:Accommodation costs for the whole trip.
12.Transportation type:The mode of transport used by the traveler, such as an airplane, train or car.
13.Transportation cost:Shipping costs for the entire trip.

# %%
LET'S VIEW SOME SPECIFIC DATA:

# %%
original_df = pd.read_csv('Travel details dataset.csv')
original_df.head()
# Out:
#    Trip ID       Destination Start date   End date  Duration (days)  \
# 0        1        London, UK   5/1/2023   5/8/2023              7.0
# 1        2  Phuket, Thailand  6/15/2023  6/20/2023              5.0
# 2        3   Bali, Indonesia   7/1/2023   7/8/2023              7.0
# 3        4     New York, USA  8/15/2023  8/29/2023             14.0
# 4        5      Tokyo, Japan  9/10/2023  9/17/2023              7.0
#
#    Traveler name  Traveler age Traveler gender Traveler nationality  \
# 0     John Smith          35.0            Male             American
# 1       Jane Doe          28.0          Female             Canadian
# 2      David Lee          45.0            Male               Korean
# 3  Sarah Johnson          29.0          Female              British
# 4     Kim Nguyen          26.0          Female           Vietnamese
#
#   Accommodation type Accommodation cost Transportation type  \
# 0              Hotel               1200              Flight
# ...

# %%
The Information of Pumpkin Seeds Data as bellow:

---

# %%
original_df.tail()
# Out:
#      Trip ID             Destination Start date   End date  Duration (days)  \
# 134      135  Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136       Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137       Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# 137      138        Barcelona, Spain  9/15/2023  9/22/2023              7.0
# 138      139   Auckland, New Zealand  10/1/2023  10/8/2023              7.0
#
#        Traveler name  Traveler age Traveler gender Traveler nationality  \
# 134       Jose Perez          37.0            Male            Brazilian
# 135      Emma Wilson          29.0          Female             Canadian
# 136        Ryan Chen          34.0            Male              Chinese
# 137  Sofia Rodriguez          25.0          Female              Spanish
# 138    William Brown          39.0            Male        New Zealander
#
#     Accommodation type Accommodation cost Transportation type  \
# ...

# %%
original_df.shape
# Out:
# (139, 13)

# %%
original_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Trip ID               139 non-null    int64
#  1   Destination           137 non-null    object
#  2   Start date            137 non-null    object
#  3   End date              137 non-null    object
#  4   Duration (days)       137 non-null    float64
#  5   Traveler name         137 non-null    object
#  6   Traveler age          137 non-null    float64
#  7   Traveler gender       137 non-null    object
#  8   Traveler nationality  137 non-null    object
#  9   Accommodation type    137 non-null    object
#  10  Accommodation cost    137 non-null    object
#  11  Transportation type   136 non-null    object
#  12  Transportation cost   136 non-null    object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 14.2+ KB

# %%
As we know, the data has 13 columns. ' Trip ID ' Columns are int64 type. 'Destination' is object type It's a fully data.

# %%
2. FEATURE OF DATA

# %%
#Feature of Data
print(f"List of unique value in Destination:\n {original_df['Destination'].unique()}")
# Out:
# List of unique value in Destination:
#  ['London, UK' 'Phuket, Thailand' 'Bali, Indonesia' 'New York, USA'
#  'Tokyo, Japan' 'Paris, France' 'Sydney, Australia'
#  'Rio de Janeiro, Brazil' 'Amsterdam, Netherlands'
#  'Dubai, United Arab Emirates' 'Cancun, Mexico' 'Barcelona, Spain'
#  'Honolulu, Hawaii' 'Berlin, Germany' 'Marrakech, Morocco'
#  'Edinburgh, Scotland' 'Paris' 'Bali' 'London' 'Tokyo' 'New York' 'Sydney'
#  'Rome' 'Bangkok' 'Hawaii' 'Barcelona' 'Japan' 'Thailand' 'France'
#  'Australia' 'Brazil' 'Greece' 'Egypt' 'Mexico' 'Italy' 'Spain' 'Canada'
#  'New York City, USA' 'Bangkok, Thailand' 'Vancouver, Canada'
#  'Sydney, AUS' 'Seoul, South Korea' 'Los Angeles, USA' 'Rome, Italy'
#  'Cape Town' nan 'Cape Town, SA' 'Sydney, Aus' 'Bangkok, Thai'
#  'Phuket, Thai' 'Dubai' 'Seoul' 'Rio de Janeiro' 'Amsterdam' 'Phuket'
#  'Santorini' 'Phnom Penh' 'Athens, Greece' 'Cape Town, South Africa'
#  'Auckland, New Zealand']

# %%
3. TARGET INFORMATIONS

# %%
original_df['Destination'].value_counts()
# Out:
# Paris                          7
# Bali                           7
# Tokyo, Japan                   7
# Paris, France                  7
# Tokyo                          5
# Sydney                         5
# Rome                           5
# New York                       5
# Bali, Indonesia                5
# Rio de Janeiro, Brazil         4
# Bangkok                        4
# Cancun, Mexico                 4
# Barcelona, Spain               4
# Rome, Italy                    4
# London                         4
# Bangkok, Thailand              3
# Sydney, Aus                    3
# London, UK                     3
# New York, USA                  3
# Sydney, Australia              3
# Vancouver, Canada              2
# New York City, USA             2
# Barcelona                      2
# Cape Town                      2
# Dubai                          2
# Amsterdam, Netherlands         2
# Bangkok, Thai                  1
# Seoul, South Korea             1
# ...

# %%
4. DESCRIBE THE TARGET ON DATA

# %%
NOW, WE'LL CHECK THE 'MEAN', 'MAX, 'MIN' VALUES,...

# %%
original_df.describe(include='all')
# Out:
#            Trip ID Destination Start date  End date  Duration (days)  \
# count   139.000000         137        137       137       137.000000
# unique         NaN          59        111       125              NaN
# top            NaN       Paris  8/15/2023  7/8/2023              NaN
# freq           NaN           7          4         3              NaN
# mean     70.000000         NaN        NaN       NaN         7.605839
# std      40.269923         NaN        NaN       NaN         1.601276
# min       1.000000         NaN        NaN       NaN         5.000000
# 25%      35.500000         NaN        NaN       NaN         7.000000
# 50%      70.000000         NaN        NaN       NaN         7.000000
# 75%     104.500000         NaN        NaN       NaN         8.000000
# max     139.000000         NaN        NaN       NaN        14.000000
#
#        Traveler name  Traveler age Traveler gender Traveler nationality  \
# ...

# %%
5. FIND OUT ANOMABLY PROBLEM

# %%
CREATE A DATASET COPY TO PROTECT ORIGINNAL DF

# %%
df = original_df.copy()

# %%
DUPLICATE DATA CHECK

# %%
dup_ind = df.duplicated()
df[dup_ind]
# Out:
# Empty DataFrame
# Columns: [Trip ID, Destination, Start date, End date, Duration (days), Traveler name, Traveler age, Traveler gender, Traveler nationality, Accommodation type, Accommodation cost, Transportation type, Transportation cost]
# Index: []

# %%
Don't have any duplicated data

# %%
FINDING MISSING DATA CHECK BY 'isnull()' FUNCTION

# %%
df.isnull().sum()*100/df.shape[0]
# Out:
# Trip ID                 0.000000
# Destination             1.438849
# Start date              1.438849
# End date                1.438849
# Duration (days)         1.438849
# Traveler name           1.438849
# Traveler age            1.438849
# Traveler gender         1.438849
# Traveler nationality    1.438849
# Accommodation type      1.438849
# Accommodation cost      1.438849
# Transportation type     2.158273
# Transportation cost     2.158273
# dtype: float64

# %%
Because our data are the number of pixel and the rating of the dimentions * Let's check the data = 0

# %%
# Basic Data Inspection
print("Data shape:", df.shape)
print("\nData types:\n", df.dtypes)
print("\nColumns with missing values:\n", (df == 0).sum())
# Out:
# Data shape: (139, 13)
#
# Data types:
#  Trip ID                   int64
# Destination              object
# Start date               object
# End date                 object
# Duration (days)         float64
# Traveler name            object
# Traveler age            float64
# Traveler gender          object
# Traveler nationality     object
# Accommodation type       object
# Accommodation cost       object
# Transportation type      object
# Transportation cost      object
# dtype: object
#
# Columns with missing values:
#  Trip ID                 0
# Destination             0
# Start date              0
# End date                0
# Duration (days)         0
# Traveler name           0
# Traveler age            0
# Traveler gender         0
# Traveler nationality    0
# Accommodation type      0
# Accommodation cost      0
# Transportation type     0
# Transportation cost     0
# dtype: int64

# %%
As we know, don't have any Value = 0. That's a good data

# %%
FIND OUTLIER

# %%
EXPLORATORY DATA ANALYSIS

# %%
UNI-VARIATE ANALYSIS

# %%
BI-VARIATE ANALYSIS

# %%
BoxPlots for all featues

# %%
Transportation type has many different types.

# %%
MULTI-VARIATE ANALYSIS

# %%
DATA VISUALIZATION

# %%
# Correlation
corr = df.drop('Accommodation type',axis=1).corr()

# Figure
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True)
plt.show()

# %%
The Accommodation type feature has a very high correlation with Trip ID and Duration (days) and Traveler age. We will try to train the model after removing the features of [ 'Destination', 'Traveler name', 'Traveler gender', 'Traveler nationality','Transportation type'].

# %%
X = df.drop('Accommodation type', axis = 1)
y = df['Accommodation type']

# %%
X1 = X.drop(columns = [ 'Destination', 'Traveler name', 'Traveler gender', 'Traveler nationality','Transportation type'], axis = 1)
y1 = df['Accommodation type']
X1.head()
# Out:
#    Trip ID Start date   End date  Duration (days)  Traveler age  \
# 0        1   5/1/2023   5/8/2023              7.0          35.0
# 1        2  6/15/2023  6/20/2023              5.0          28.0
# 2        3   7/1/2023   7/8/2023              7.0          45.0
# 3        4  8/15/2023  8/29/2023             14.0          29.0
# 4        5  9/10/2023  9/17/2023              7.0          26.0
#
#   Accommodation cost Transportation cost
# 0               1200                 600
# 1                800                 500
# 2               1000                 700
# 3               2000                1000
# 4                700                 200

# %%
# Import sklearn.preprocessing.StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
X1.columns
# Out:
# Index(['Trip ID', 'Destination', 'Start date', 'End date', 'Duration (days)',
#        'Traveler name', 'Traveler gender', 'Traveler nationality',
#        'Accommodation cost', 'Transportation type', 'Transportation cost'],
#       dtype='object')

# %%
X1=X1[numerical]
X1.head()
# Out:
#    Trip ID Start date   End date  Duration (days)  Traveler age  \
# 0        1   5/1/2023   5/8/2023              7.0          35.0
# 1        2  6/15/2023  6/20/2023              5.0          28.0
# 2        3   7/1/2023   7/8/2023              7.0          45.0
# 3        4  8/15/2023  8/29/2023             14.0          29.0
# 4        5  9/10/2023  9/17/2023              7.0          26.0
#
#   Accommodation cost Transportation cost
# 0               1200                 600
# 1                800                 500
# 2               1000                 700
# 3               2000                1000
# 4                700                 200
